# %%
# Dependencies
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import seaborn as sns
sns.set(color_codes=True)


# Google developer API key
gkey='AIzaSyApeF7ERvT-pj38Y3qau5D6I7eM6g-MbWc'
headers = {"Authorization": "Bearer MorDAXlhkrcLM04Ek5Ya0vBT7A1rG4OZMGSb8Sqc6rE_AMcSF3pIq5Ed43YrWd6xsaQfi82g-MChCLNhh0Z-G7HrUUXkL7wd4kUesLg3quXFia-B5sBOJhHvAwfEWnYx"}

# %%
#Don't Run This. It takes forever. Also saved data in pickle file
#lats=[]
#longs=[]
#counter=0
#for i in monuments:
#        # Target city
#    target_city = i

    # Build the endpoint URL
#    target_url = "https://maps.googleapis.com/maps/api/geocode/json?" \
#    "address=%s&key=%s" % (target_city, gkey)
#    geo_data = requests.get(target_url).json()

    # Print the json
#    counter+=1
#    try:
#        lats.append(geo_data['results'][0]['geometry']['location']['lat'])
#        longs.append(geo_data['results'][0]['geometry']['location']['lng'])
#    except:
#        print(counter)
#        break

# %%
# Unpickling (Saved Lists)
with open("lats.txt", "rb") as fp:   
    lats = pickle.load(fp)
with open("longs.txt", "rb") as fp:   
    longs = pickle.load(fp)
with open("monuments.txt", "rb") as fp:   
    monuments = pickle.load(fp)

# %%
dist=[]
price=[]
country=[]
rating=[]
reviewcount=[]
types=[]
monument=[]
ids=[]
for i in range(len(lats)):
    a=requests.get(f'https://api.yelp.com/v3/businesses/search?latitude={lats[i]}&longitude={longs[i]}',headers=headers).json()
    for j in a['businesses']:
        dist.append(j['distance'])
        country.append(j['location']['country'])
        rating.append(j['rating'])
        reviewcount.append(j['review_count'])
        monument.append(monuments[i])
        ids.append(j['id'])
        try:
            price.append(len(j['price']))
        except:
            price.append('n/a')
        try:
            types.append(j['categories'][0]['title'])
        except:
            types.append('n/a')

# %%
jds=[]
for i in range(len(lats)):
    a=requests.get(f'https://api.yelp.com/v3/businesses/search?latitude={lats[i]}&longitude={longs[i]}',headers=headers).json()
    for j in a['businesses']:
        try:
            jds.append(j['id'])
        except:
            break

# %%
jds
# Out:
# ['statue-of-liberty-new-york-3',
#  'ellis-island-immigration-museum-new-york',
#  'governors-island-national-monument-new-york',
#  'liberty-state-park-jersey-city',
#  'hometown-bar-b-que-brooklyn',
#  'taqueria-downtown-jersey-city',
#  'razza-pizza-artigianale-jersey-city-2',
#  'bucket-and-bay-craft-gelato-jersey-city-5',
#  'sam-a-m-jersey-city-2',
#  'kraverie-jersey-city',
#  'orale-mexican-kitchen-jersey-city',
#  'brownstone-diner-and-pancake-factory-jersey-city',
#  'me-casa-restaurant-and-catering-jersey-city',
#  'satis-bistro-jersey-city',
#  'just-beclaws-jersey-city',
#  'pr-and-ince-jersey-city-2',
#  'liberty-house-restaurant-jersey-city-2',
#  'skinners-loft-jersey-city',
#  'hooked-jc-jersey-city',
#  'vogue-café-jersey-city-2',
#  'la-tour-eiffel-paris-4',
#  'les-cocottes-paris',
#  'le-jules-verne-paris',
#  'le-volant-basque-paris',
#  'arc-de-triomphe-paris-2',
#  'café-constant-paris-2',
#  'la-coïncidence-paris-4',
#  'la-fontaine-de-mars-paris-2',
#  'kozy-paris-6',
#  'le-petit-cler-paris',
#  'l-ami-jean-paris-2',
#  'le-relais-de-l-entrecôte-paris-3',
#  '58-tour-eiffel-paris',
#  'firmine-paris',
#  'monsieur-bleu-paris',
#  'le-bosquet-paris',
#  'le-violon-d-ingres-paris',
#  'pottoka-paris',
#  'le-cinq-paris',
#  'david-toutain-paris',
#  'big-ben-london',
#  'dishoom-london',
#  'coca-cola-london-eye-london',
#  'westminster-abbey-london',
#  'regency-café-london-2',
#  'gordons-wine-bar-london-4',
#  'houses-of-parliament-london-3',
#  'churchill-war-rooms-london-2',
#  'st-jamess-park-london-2',
#  'hawksmoor-seven-dials-london-4',
#  'the-wolseley-london',
#  'monmouth-coffee-london-3',
#  'yauatcha-london-7',
#  'hyde-park-london-2',
#  'punjab-london',
#  'flat-iron-london-2',
#  'honest-burgers-london-2',
#  'dishoom-london-7',
#  'nopi-london',
#  'burger-and-lobster-london-2',
#  'torre-di-pisa-pisa',
#  'il-peperoncino-pisa',
#  'piazza-dei-miracoli-pisa',
#  'l-ostellino-pisa',
#  'cattedrale-di-santa-maria-assunta-pisa',
#  'quarto-d-ora-italiano-pisa',
#  'la-taverna-di-emma-pisa-2',
#  'leaning-tower-di-cioffi-alfonso-e-c-pisa',
#  'pastamania-italia-pisa',
#  'trattoria-della-faggiola-pisa',
#  'pizzeria-il-montino-pisa-3',
#  'dolcepisa-pisa',
#  'la-buca-pisa',
#  'antica-bottega-di-pisa-pisa',
#  'osteria-dei-cavalieri-pisa',
#  'numero-undici-pisa',
#  'la-cicala-pisa',
#  'i-porci-comodi-pisa',
#  'piazza-dei-cavalieri-pisa-2',
#  'indiano-india-pisa',
#  'colosseo-roma',
#  'sapori-e-delizie-roma-2',
#  'ai-tre-scalini-roma',
#  'pane-e-vino-roma-4',
#  'foro-romano-roma-4',
#  'fontana-di-trevi-roma-3',
#  'la-prosciutteria-trevi-roma-2',
#  'pantheon-basilica-di-santa-maria-ad-martyres-roma',
#  'fatamorgana-roma-3',
#  'frigidarium-roma',
#  'la-casa-del-tazza-d-oro-roma',
#  'pasta-chef-roma',
#  'osteria-barberini-roma',
#  'thats-amore-roma-2',
#  'da-francesco-roma',
#  'la-taverna-dei-fori-imperiali-roma',
#  'da-enzo-al-29-roma-2',
#  'alessio-roma',
#  'pane-e-salame-roma-2',
#  'pinsere-roma',
#  'shake-shack-new-york-2',
#  'best-bagel-and-coffee-new-york',
#  'the-halal-guys-new-york-2',
#  'eleven-madison-park-new-york',
#  'eataly-new-york',
#  'izakaya-mew-new-york-3',
#  'keens-steakhouse-new-york',
#  'woorijip-authentic-korean-food-new-york',
#  'grand-central-terminal-new-york',
#  'bryant-park-new-york-2',
#  'grace-street-new-york',
#  'scarpetta-new-york',
#  'empire-state-building-new-york-2',
#  'stumptown-coffee-roasters-new-york',
#  'ilili-new-york-2',
#  'ippudo-east-village-new-york',
#  'burger-and-lobster-new-york',
#  'gramercy-tavern-new-york',
#  'turntable-chicken-jazz-new-york-2',
#  'the-nomad-restaurant-new-york',
#  'hollywood-sign-los-angeles-4',
#  'portos-bakery-and-cafe-burbank',
#  'bea-beas-burbank',
#  'cleo-los-angeles',
#  'lake-hollywood-park-los-angeles',
#  'dog-haus-burbank',
#  'the-trails-los-angeles',
#  'lake-hollywood-reservoir-hollywood',
#  'bronson-canyon-griffith-park-hollywood',
#  'the-magic-castle-hollywood',
#  'olive-and-thyme-toluca-lake-2',
#  'veggie-house-los-angeles-2',
#  'los-amigos-restaurant-bar-and-grill-burbank',
#  'a-simple-bar-los-angeles',
#  'palms-thai-restaurant-los-angeles-2',
#  'lou-the-french-on-the-block-burbank-2',
#  'mojo-hookah-lounge-los-angeles-6',
#  'runyon-canyon-park-los-angeles-2',
#  'bobs-big-boy-burbank-burbank',
#  'the-smoke-house-restaurant-burbank-2',
#  'golden-gate-bridge-san-francisco',
#  'fort-point-san-francisco',
#  'marin-headlands-sausalito',
#  'chapeau-san-francisco',
#  'baker-beach-san-francisco',
#  'genki-crepes-and-mini-mart-san-francisco',
#  'mandalay-san-francisco',
#  'spruce-san-francisco',
#  'battery-spencer-sausalito-2',
#  'pizzetta-211-san-francisco',
#  'vista-point-sausalito',
#  'lands-end-san-francisco',
#  'the-presidio-san-francisco',
#  'good-luck-dim-sum-san-francisco',
#  'murray-circle-sausalito',
#  'sakesan-bistro-san-francisco',
#  'napa-valley-burger-company-sausalito',
#  'cafe-europa-san-francisco',
#  'yoda-fountain-at-lucasfilm-san-francisco',
#  'warming-hut-cafe-san-francisco',
#  'cathédrale-notre-dame-de-paris-paris',
#  'l-as-du-fallafel-paris',
#  'l-avant-comptoir-paris-3',
#  'le-bistro-du-périgord-paris-3',
#  'sainte-chapelle-paris',
#  'comptoir-de-la-gastronomie-paris-4',
#  'jardin-du-luxembourg-paris',
#  'le-bistrot-des-augustins-paris',
#  'la-jacobine-paris',
#  'la-droguerie-du-marais-paris',
#  'chez-le-libanais-paris',
#  'le-comptoir-paris-18',
#  'le-petit-pontoise-paris',
#  'le-temps-des-cerises-paris-5',
#  'la-caféothèque-paris-2',
#  'le-reminet-paris-3',
#  'ze-kitchen-galerie-paris',
#  'chez-gladines-paris-2',
#  'chez-fernand-paris',
#  'pain-vin-fromages-paris',
#  '東京タワー-港区-2',
#  '寿司大-中央区',
#  '東京-芝-とうふ屋-うかい-港区',
#  'すきやばし次郎-六本木ヒルズ店-港区',
#  '大和寿司-中央区',
#  '一風堂-銀座店-中央区-4',
#  '久兵衛-銀座本店-中央区',
#  'エッグセレント-港区-3',
#  'ジョウモン-六本木店-港区-2',
#  'イマカツ-六本木本店-港区',
#  'すし匠-まさ-港区',
#  '一蘭-六本木店-港区',
#  '六厘舎-千代田区',
#  'ts-たんたん-東京駅京葉ストリート店-千代田区-2',
#  '听屋-六本木-港区-2',
#  '511-港区-4',
#  '阿夫利-麻布十番-港区',
#  'デビルクラフト-浜松町店-港区',
#  '福気-港区',
#  'ターレット-コーヒー-中央区',
#  'dishoom-london',
#  'coca-cola-london-eye-london',
#  'big-ben-london',
#  'westminster-abbey-london',
#  'gordons-wine-bar-london-4',
#  'regency-café-london-2',
#  'hawksmoor-seven-dials-london-4',
#  'churchill-war-rooms-london-2',
#  'houses-of-parliament-london-3',
#  'st-jamess-park-london-2',
#  'monmouth-coffee-london-3',
#  'punjab-london',
#  'the-wolseley-london',
#  'yauatcha-london-7',
#  'honest-burgers-london-2',
#  'flat-iron-london-2',
#  'dishoom-london-7',
#  'flat-iron-covent-garden',
#  'ye-olde-cheshire-cheese-london',
#  'homeslice-neals-yard-london',
#  'bonci-roma-2',
#  'piazza-san-pietro-roma-2',
#  'pizza-zizza-roma',
#  'frigidarium-roma',
#  'pantheon-basilica-di-santa-maria-ad-martyres-roma',
#  'da-francesco-roma',
#  'pastasciutta-roma',
#  'da-vito-e-dina-roma',
#  'angrypig-birretta-e-porchetta-roma',
#  'la-casa-del-tazza-d-oro-roma',
#  'duecento-gradi-roma-2',
#  'piazza-navona-roma',
#  'dar-poeta-roma',
#  'la-botticella-roma',
#  'osteria-da-fortunata-roma',
#  'santeustachio-il-caffè-roma-2',
#  'da-simo-pane-e-vino-roma-2',
#  'cantina-e-cucina-roma',
#  'su-e-giu-cucina-romana-roma',
#  'pane-e-salame-roma-2',
#  'basílica-de-la-sagrada-família-barcelona',
#  'cervecería-catalana-barcelona-2',
#  'la-pepita-barcelona',
#  'la-paradeta-barcelona-9',
#  'casa-batlló-barcelona-4',
#  'ciudad-condal-barcelona',
#  'parc-güell-barcelona-7',
#  'paisano-café-barcelona-3',
#  'brunch-y-cake-barcelona-2',
#  'casa-lolea-barcelona',
#  'tucco-real-food-barcelona',
#  'la-pedrera-casa-milà-barcelona',
#  'teresa-carles-barcelona',
#  'cera-23-barcelona',
#  'alsur-café-llúria-barcelona-2',
#  'la-taqueria-barcelona',
#  'gata-mala-barcelona',
#  'tapeo-barcelona-3',
#  'granja-petitbo-barcelona',
#  'eden-barcelona-2',
#  '50s-prime-time-cafe-lake-buena-vista-2',
#  'sci-fi-dine-in-theater-restaurant-orlando-2',
#  'the-hollywood-brown-derby-orlando-2',
#  'le-cellier-steakhouse-orlando-3',
#  'via-napoli-lake-buena-vista-2',
#  'flying-fish-orlando-2',
#  'boulangerie-patisserie-orlando-4',
#  'rose-and-crown-dining-room-orlando-2',
#  'la-cava-del-tequila-lake-buena-vista',
#  'biergarten-restaurant-orlando',
#  'mama-melroses-ristorante-italiano-orlando-3',
#  'yorkshire-county-fish-shop-lake-buena-vista',
#  'chefs-de-france-orlando-3',
#  'shulas-steak-house-lake-buena-vista-2',
#  'bull-and-bear-orlando-2',
#  'beaches-and-cream-soda-shop-orlando-2',
#  'todd-englishs-bluezoo-orlando',
#  'teppan-edo-orlando-2',
#  'yak-and-yeti-restaurant-lake-buena-vista',
#  'cape-may-cafe-orlando-3',
#  'sydney-opera-house-sydney',
#  'mr-wong-sydney',
#  'sydney-harbour-bridge-sydney',
#  'the-fine-food-store-the-rocks-2',
#  'saké-sydney',
#  'rockpool-bar-and-grill-sydney',
#  'the-baxter-inn-sydney',
#  'quay-restaurant-sydney-4',
#  'bulletin-place-sydney',
#  'cafe-sydney-circular-quay',
#  'la-renaissance-cafe-patisserie-the-rocks',
#  'mamak-haymarket-3',
#  'bennelong-restaurant-sydney-3',
#  'din-tai-fung-sydney-5',
#  'harrys-cafe-de-wheels-woolloomooloo-4',
#  'queen-victoria-building-sydney',
#  'circular-quay-sydney',
#  'ippudo-sydney-sydney-2',
#  'frankies-pizza-sydney',
#  'the-rocks-cafe-the-rocks',
#  'arc-de-triomphe-paris-2',
#  'la-tour-eiffel-paris-4',
#  'la-coïncidence-paris-4',
#  'le-hide-paris-2',
#  'le-relais-de-l-entrecôte-paris-3',
#  'le-cinq-paris',
#  'l-atelier-de-joël-robuchon-paris-3',
#  'lac-hong-paris',
#  'les-cocottes-paris',
#  'framboise-paris-20',
#  'taillevent-paris',
#  'chez-gabrielle-paris',
#  'le-relais-de-venise-l-entrecôte-paris-2',
#  'avenue-des-champs-élysées-paris-3',
#  'le-music-hall-paris',
#  'le-jules-verne-paris',
#  'l-epicure-paris-2',
#  'monsieur-bleu-paris',
#  'pierre-gagnaire-paris',
#  'sir-winston-paris',
#  'brandenburger-tor-berlin',
#  'yarok-berlin',
#  'cocolo-ramen-berlin',
#  'dada-falafel-berlin',
#  'monsieur-vuong-berlin',
#  'transit-berlin',
#  'papà-pane-di-sorrento-berlin-2',
#  'dudu-berlin',
#  'factory-girl-berlin-2',
#  'shiso-burger-berlin',
#  'deutscher-bundestag-reichstagsgebäude-berlin',
#  'dolores-berlin',
#  'schwarzwaldstuben-berlin',
#  'clärchens-ballhaus-berlin-2',
#  'kopps-berlin',
#  'toca-rouge-berlin',
#  'katz-orange-berlin',
#  'reinstoff-berlin-2',
#  'the-bird-berlin',
#  'rausch-schokoladenhaus-berlin-2',
#  'stonehenge-amesbury-2',
#  'black-horse-salisbury-3',
#  'uluru-kata-tjuta-national-park-petermann',
#  'bough-house-restaurant-uluru',
#  'tower-of-london-london-2',
#  'tower-bridge-london-4',
#  'monmouth-coffee-london',
#  'sky-garden-london-2',
#  'duck-and-waffle-london',
#  'tayyabs-london-3',
#  'dishoom-london-2',
#  'st-pauls-cathedral-london-4',
#  'josé-london-2',
#  'exmouth-coffee-company-london',
#  'the-shard-london-3',
#  'swan-london-2',
#  'hawksmoor-spitalfields-london-6',
#  'padella-london-3',
#  'the-table-cafe-london-5',
#  'bravas-tapas-london',
#  'st-john-bar-and-restaurant-london',
#  'mango-indian-london',
#  'the-gherkin-swiss-re-tower-london-2',
#  'the-garrison-london',
#  'roses-luxury-washington',
#  'ambar-washington',
#  'teds-bulletin-washington',
#  'library-of-congress-washington-3',
#  'cava-mezze-washington-6',
#  'barrel-washington',
#  'good-stuff-eatery-washington',
#  'acqua-al-2-washington',
#  'toki-underground-washington',
#  'sushi-capitol-washington-3',
#  'rasika-washington',
#  'peregrine-espresso-washington-2',
#  'zaytinya-washington',
#  'matchbox-capitol-hill-washington',
#  'tortilla-cafe-washington',
#  'montmartre-washington',
#  'pineapple-and-pearls-washington-3',
#  'and-pizza-washington-28',
#  'bistro-cacao-washington-2',
#  'market-lunch-washington-2',
#  'girl-and-the-goat-chicago',
#  'wildberry-pancakes-and-cafe-chicago-2',
#  'au-cheval-chicago',
#  'art-institute-of-chicago-chicago-3',
#  'the-purple-pig-chicago',
#  'bavettes-bar-and-boeuf-chicago',
#  'little-goat-diner-chicago-4',
#  'avec-chicago',
#  'lou-malnatis-pizzeria-chicago',
#  'the-gage-chicago',
#  'xoco-chicago',
#  'portillos-hot-dogs-and-barnellis-salad-bowl-chicago',
#  'millennium-park-chicago',
#  'quartino-ristorante-chicago',
#  'joes-seafood-prime-steak-and-stone-crab-chicago',
#  'the-publican-chicago',
#  'cafecito-chicago',
#  'rpm-italian-chicago',
#  'do-rite-donuts-and-coffee-chicago-2',
#  'willis-tower-chicago-3',
#  'brooklyn-bridge-brooklyn',
#  'julianas-pizza-brooklyn-5',
#  'grimaldis-brooklyn-4',
#  'katzs-delicatessen-new-york',
#  'doughnut-plant-new-york-4',
#  'brooklyn-bridge-park-brooklyn-3',
#  'joes-shanghai-new-york-2',
#  'ippudo-east-village-new-york',
#  'the-river-café-brooklyn-3',
#  'lombardis-pizza-new-york',
#  'clinton-street-baking-company-new-york-5',
#  'fishmarket-restaurant-new-york',
#  'prince-street-pizza-new-york-2',
#  'breakroom-new-york',
#  'cheeky-sandwiches-new-york',
#  'cafe-habana-new-york-4',
#  'the-boil-new-york-3',
#  '88-lan-zhou-handmade-noodles-and-dumplings-new-york',
#  'wah-fung-no-1-new-york',
#  'beauty-and-essex-new-york',
#  'fontana-di-trevi-roma-3',
#  'la-prosciutteria-trevi-roma-2',
#  'pantheon-basilica-di-santa-maria-ad-martyres-roma',
#  'colosseo-roma',
#  'frigidarium-roma',
#  'thats-amore-roma-2',
#  'la-casa-del-tazza-d-oro-roma',
#  'pane-e-salame-roma-2',
#  'osteria-barberini-roma',
#  'ai-tre-scalini-roma',
#  'da-francesco-roma',
#  'santeustachio-il-caffè-roma-2',
#  'piazza-navona-roma',
#  'sapori-e-delizie-roma-2',
#  'foro-romano-roma-4',
#  'life-roma',
#  'osteria-da-fortunata-roma',
#  'osteria-quarantaquattro-roma',
#  'sofia-roma',
#  'alessio-roma',
#  'dal-moros-venezia',
#  'rossopomodoro-venezia',
#  'basilica-di-san-marco-venezia',
#  'osteria-alla-staffa-venezia',
#  'palazzo-ducale-venezia',
#  'a-le-tole-venezia',
#  'trattoria-al-gazzettino-venezia-4',
#  'canal-grande-venezia-2',
#  'antico-forno-venezia',
#  'caffè-florian-venezia',
#  'alla-rivetta-venezia',
#  'la-zucca-venezia',
#  'da-mamo-venezia-4',
#  'osteria-enoteca-san-marco-venezia',
#  'osteria-oliva-nera-venezia-2',
#  'al-chianti-venezia',
#  'cantina-do-mori-venezia',
#  'ponte-di-rialto-venezia-2',
#  'la-rosa-rossa-venezia-2',
#  'la-caravella-venezia',
#  'the-halal-guys-new-york-2',
#  'bibble-and-sip-new-york-2',
#  'le-bernardin-new-york',
#  'del-friscos-double-eagle-steak-house-new-york-2',
#  'totto-ramen-new-york',
#  'juniors-cheesecake-new-york-3',
#  'ippudo-westside-new-york',
#  'top-of-the-rock-new-york',
#  'carmines-italian-restaurant-times-square-new-york-3',
#  'best-bagel-and-coffee-new-york',
#  'bryant-park-new-york-2',
#  'grand-central-terminal-new-york',
#  'pure-thai-cookhouse-new-york',
#  'shake-shack-new-york-9',
#  'tonys-di-napoli-new-york-4',
#  'trattoria-trecolori-new-york',
#  'keens-steakhouse-new-york',
#  'bea-new-york',
#  'izakaya-mew-new-york-3',
#  'schmackarys-new-york',
#  'founding-farmers-d-c-washington-2',
#  'old-ebbitt-grill-washington',
#  'zaytinya-washington',
#  'rasika-washington',
#  'lincoln-memorial-washington-2',
#  'fogo-de-chão-brazilian-steakhouse-washington-5',
#  'le-diplomate-washington',
#  'joes-seafood-prime-steak-and-stone-crab-washington',
#  'blue-duck-tavern-washington',
#  'the-hamilton-washington',
#  'and-pizza-washington-11',
#  'matchbox-chinatown-washington',
#  'baked-and-wired-washington',
#  'daikaya-ramen-shop-washington-2',
#  'the-white-house-washington',
#  'district-taco-washington-6',
#  'and-pizza-washington-15',
#  'the-pig-washington-2',
#  'tabard-inn-restaurant-washington-2',
#  'bub-and-pops-washington',
#  'comptoir-de-la-gastronomie-paris-4',
#  'cathédrale-notre-dame-de-paris-paris',
#  'l-as-du-fallafel-paris',
#  'sanukiya-paris',
#  'l-avant-comptoir-paris-3',
#  'claus-la-table-du-petit-déjeuner-paris',
#  'sainte-chapelle-paris',
#  'l-atelier-de-joël-robuchon-paris-2',
#  'pyramide-du-louvre-paris',
#  'la-jacobine-paris',
#  'le-bistrot-des-augustins-paris',
#  'le-relais-de-l-entrecôte-paris-4',
#  'little-breizh-paris',
#  'jardin-du-luxembourg-paris',
#  'le-fumoir-paris',
#  'verjus-paris',
#  'le-pont-des-arts-paris-2',
#  'ze-kitchen-galerie-paris',
#  'chez-le-libanais-paris',
#  'le-bistro-du-périgord-paris-3',
#  'grand-place-de-bruxelles-bruxelles',
#  'peck-47-bruxelles',
#  'bia-mara-city-of-brussels',
#  'mer-du-nord-bruxelles-5',
#  'delirium-café-bruxelles-2',
#  'moeder-lambic-bruxelles-3',
#  'le-fin-de-siècle-bruxelles-2',
#  'nüetnigenough-bruxelles-3',
#  'rachel-bruxelles-2',
#  'pasta-divina-bruxelles',
#  'le-poechenellekelder-bruxelles',
#  'houtsiplou-bruxelles',
#  'winehouse-osteria-bruxelles',
#  'boulangerie-charli-bruxelles-2',
#  'goupil-le-fol-bruxelles',
#  'les-filles-bruxelles',
#  'osteria-bolognese-ixelles',
#  'jat-café-bruxelles',
#  'colonel-saint-gilles',
#  'manneken-pis-bruxelles-3',
#  'dishoom-london',
#  'hyde-park-london-2',
#  'big-ben-london',
#  'coca-cola-london-eye-london',
#  'westminster-abbey-london',
#  'regency-café-london-2',
#  'dishoom-london-7',
#  'st-jamess-park-london-2',
#  'the-wolseley-london',
#  'sketch-london-2',
#  'dinner-by-heston-blumenthal-london',
#  'gordons-wine-bar-london-4',
#  'buckingham-palace-london',
#  'churchill-war-rooms-london-2',
#  'flat-iron-london-2',
#  'burger-and-lobster-london',
#  'yauatcha-london-7',
#  'nopi-london',
#  'mother-mash-london',
#  'houses-of-parliament-london-3',
#  'château-de-versailles-versailles-3',
#  'les-jardins-du-château-de-versailles-versailles',
#  'gordon-ramsay-au-trianon-versailles',
#  'le-boeuf-à-la-mode-versailles-2',
#  'chez-lazare-versailles-2',
#  'angelina-versailles',
#  'chez-stefs-versailles',
#  'la-place-versailles-2',
#  'la-tour-versailles',
#  'palais-de-marakech-versailles',
#  'chez-tiouiche-versailles',
#  'crêperie-du-phare-saint-louis-versailles',
#  'le-limousin-versailles',
#  'l-aparthé-versailles-2',
#  'pizza-via-veneto-versailles-2',
#  'la-véranda-versailles-2',
#  'sisters-café-versailles-2',
#  'l-equilibre-versailles-2',
#  'le-bistro-du-boucher-versailles',
#  'o-paris-versailles',
#  'schloss-neuschwanstein-schwangau-3',
#  'schloss-hohenschwangau-schwangau',
#  'schloßrestaurant-neuschwanstein-schwangau-3',
#  'marienbrücke-schwangau',
#  's-wirtshaus-im-weinbauer-schwangau-2',
#  'restaurant-müller-schwangau',
#  'schloss-brauhaus-schwangau-2',
#  'alpenrose-am-see-schwangau',
#  'allgäuer-stüberl-schwangau',
#  'kainz-schwangau',
#  'restauarnt-helmer-schwangau',
#  'das-rübezahl-schwangau',
#  'restaurant-hanselewirt-schwangau',
#  'gasthof-am-see-schwangau-2',
#  'restaurant-waldmann-schwangau',
#  'drehhütte-schwangau',
#  'cafe-bistro-neuschwanstein-schwangau',
#  'landgasthof-zur-post-schwangau-2',
#  'asia-im-hotel-wildpark-schwangau',
#  'pizzeria-san-marco-schwangau',
#  'berghaus-matterhorn-hörnlihütte-zermatt',
#  'lo-copa-pan-bar-et-cuisine-breuil-cervinia',
#  'bontadini-breuil-cervinia',
#  'grivola-breuil-cervinia',
#  'restaurant-stafelalp-zermatt',
#  'al-forte-breuil-cervinia',
#  'ski-d-oro-breuil-cervinia',
#  'addu-mimi-pompei',
#  'scavi-di-pompei-pompei',
#  'vincanto-pompei',
#  'betolla-del-gusto-pompei',
#  'de-vivo-pompei',
#  'stuzzico-di-lucias-pompei',
#  'president-pompei-2',
#  'ristorante-garum-pompei',
#  'il-machiavelli-pompei',
#  'zi-caterina-pompei',
#  'hotel-forum-pompei-2',
#  'misaki-sushi-pompei',
#  'banana-republics-pompei',
#  'pizzeria-alleria-pompei',
#  'il-principe-pompei-2',
#  'addò-trammiere-il-maradona-della-pizza-pompei',
#  'hostaria-plinio-pompei',
#  'hcca24-pompei',
#  'suisse-pompei-2',
#  'mascolo-pompei',
#  'allantico-vinaio-firenze',
#  'mercato-centrale-firenze-firenze-2',
#  'la-giostra-firenze',
#  'pensavo-peggio-firenze',
#  'trattoria-zà-zà-firenze-5',
#  'gelateria-dei-neri-firenze',
#  'la-prosciutteria-firenze-2',
#  'mangia-pizza-firenze',
#  'trattoria-da-mario-firenze',
#  'gli-uffizi-firenze',
#  'osteria-del-cinghiale-bianco-firenze',
#  'trattoria-dalloste-firenze-2',
#  'i-2-fratellini-firenze',
#  'vini-e-vecchi-sapori-firenze',
#  'cattedrale-di-santa-maria-del-fiore-firenze',
#  'buca-mario-firenze',
#  'le-vespe-cafe-firenze',
#  'ponte-vecchio-firenze',
#  'gusta-pizza-firenze',
#  'l-osteria-di-giovanni-firenze',
#  'edinburgh-castle-edinburgh',
#  'the-devils-advocate-edinburgh',
#  'oink-edinburgh',
#  'the-outsider-edinburgh',
#  'hula-juice-cafe-edinburgh',
#  'the-edinburgh-larder-edinburgh',
#  'mums-edinburgh',
#  'the-hanging-bat-beer-cafe-edinburgh',
#  'princes-street-edinburgh-3',
#  'the-baked-potato-shop-edinburgh',
#  'royal-mile-edinburgh',
#  'the-dogs-edinburgh',
#  'mussel-inn-edinburgh',
#  'the-mussel-and-steak-bar-edinburgh',
#  'bramble-edinburgh-2',
#  'brew-lab-edinburgh-2',
#  'affogato-edinburgh',
#  'gurkha-cafe-and-restaurant-edinburgh',
#  'calton-hill-edinburgh',
#  'wings-edinburgh-edinburgh',
#  'cristo-redentor-corcovado-rio-de-janeiro',
#  'parque-lage-rio-de-janeiro',
#  'meza-bar-rio-de-janeiro',
#  'comuna-rio-de-janeiro',
#  'ct-boucherie-rio-de-janeiro',
#  'aprazível-rio-de-janeiro-2',
#  'mamma-jamma-rio-de-janeiro',
#  'via-sete-rio-de-janeiro',
#  'bráz-rio-de-janeiro-2',
#  'pavão-azul-rio-de-janeiro',
#  'empório-jardim-rio-de-janeiro-2',
#  'bar-sobe-rio-de-janeiro',
#  'prana-vegetariano-rio-de-janeiro',
#  'lima-restobar-rio-de-janeiro',
#  'la-carioca-cevicheria-rio-de-janeiro',
#  'bar-teto-solar-rio-de-janeiro',
#  'la-bicyclette-rio-de-janeiro-4',
#  'restaurante-olympe-rio-de-janeiro',
#  'irajá-gastrô-rio-de-janeiro',
#  'joaquina-bar-e-restaurante-rio-de-janeiro-5',
#  'pai-northern-thai-kitchen-toronto-5',
#  'byblos-toronto-2',
#  'khao-san-road-toronto',
#  'banh-mi-boys-toronto',
#  'richmond-station-toronto',
#  'jacobs-and-co-steakhouse-toronto',
#  'cn-tower-toronto',
#  'canoe-toronto-2',
#  'miku-toronto-toronto',
#  'ravi-soups-toronto',
#  'seven-lives-tacos-y-mariscos-toronto',
#  'wvrst-toronto',
#  '360-restaurant-toronto-2',
#  'jabistro-toronto-2',
#  'lee-restaurant-toronto-3',
#  'gusto-101-toronto',
#  'alo-restaurant-toronto',
#  'beerbistro-toronto-3',
#  'bar-hop-toronto',
#  'kinka-izakaya-original-toronto',
#  'niagara-falls-niagara-falls-2',
#  'niagara-falls-state-park-niagara-falls-2',
#  'cave-of-the-winds-niagara-falls',
#  'third-street-retreat-niagara-falls-2',
#  'weinkeller-niagara-falls',
#  'zaika-indian-cuisine-niagara-falls',
#  'ag-niagara-falls',
#  'napoli-ristorante-and-pizzeria-niagara-falls',
#  'koutouki-greek-cuisine-niagara-falls',
#  'the-keg-steakhouse-and-bar-niagara-falls-9',
#  'antica-pizzeria-niagara-falls',
#  'sandstone-grillhouse-niagara-falls',
#  'donatellos-restaurant-niagara-falls',
#  'pho-xyclo-niagara-falls-2',
#  'savor-niagara-falls',
#  'smokes-poutinerie-niagara-falls',
#  'canyon-creek-niagara-falls',
#  'taki-japanese-restaurant-niagara-falls',
#  'paris-crepes-cafe-niagara-falls',
#  'brasa-brazilian-steakhouse-and-wine-bar-niagara-falls',
#  'tower-of-london-london-2',
#  'tower-bridge-london-4',
#  'duck-and-waffle-london',
#  'monmouth-coffee-london',
#  'sky-garden-london-2',
#  'tayyabs-london-3',
#  'dishoom-london-2',
#  'st-pauls-cathedral-london-4',
#  'exmouth-coffee-company-london',
#  'josé-london-2',
#  'hawksmoor-spitalfields-london-6',
#  'sushisamba-london-london-4',
#  'the-shard-london-3',
#  'swan-london-2',
#  'pizza-union-london-3',
#  'the-gherkin-swiss-re-tower-london-2',
#  'the-table-cafe-london-5',
#  'byward-kitchen-and-bar-london',
#  'padella-london-3',
#  'st-john-bar-and-restaurant-london',
#  'chocolatería-san-ginés-madrid-6',
#  'palacio-real-madrid',
#  'takos-al-pastor-madrid',
#  'botín-madrid-3',
#  'el-sur-madrid',
#  'museo-nacional-del-prado-madrid-3',
#  'casa-lucas-madrid',
#  'templo-de-debod-madrid',
#  'plaza-mayor-madrid',
#  'museo-del-jamón-madrid-6',
#  'alhambra-madrid-3',
#  'casa-federica-madrid',
#  'toma-café-madrid-2',
#  'juana-la-loca-madrid-2',
#  'yerbabuena-madrid',
#  'malaspina-madrid',
#  'rosi-la-loca-madrid',
#  'la-mi-venta-madrid',
#  'café-de-la-luz-madrid-2',
#  '1862-dry-bar-madrid',
#  'mont-saint-michel-le-mont-saint-michel-2',
#  'la-sirène-mont-saint-michel-le',
#  'la-ferme-saint-michel-beauvoir',
#  'la-mère-poulard-restaurant-le-mont-st-michel',
#  'restaurant-les-terrasses-poulard-le-mont-saint-michel',
#  'le-relais-du-roy-romazy',
#  'la-croix-blanche-restaurant-le-mont-saint-michel',
#  'creperie-du-chapeau-rouge-le-mont-st-michel',
#  'la-rotisserie-mont-saint-michel',
#  'la-cloche-le-mont-saint-michel',
#  'la-vieille-auberge-mont-saint-michel-le-3',
#  'auberge-saint-pierre-restaurant-le-mont-saint-michel',
#  'nouvelles-terrasses-les-mont-saint-michel-le',
#  'le-tripot-le-mont-saint-michel',
#  'la-fermette-beauvoir',
#  'le-pre-sale-le-mont-saint-michel',
#  'au-pèlerin-le-mont-saint-michel',
#  'la-confiance-le-mont-saint-michel',
#  'marée-time-beauvoir-3',
#  'le-beauvoir-beauvoir',
#  'carson-kitchen-las-vegas',
#  'eat-las-vegas-2',
#  'pizza-rock-las-vegas',
#  'vegenation-las-vegas',
#  'le-thai-las-vegas',
#  'hugos-cellar-las-vegas',
#  'vic-and-anthonys-steakhouse-las-vegas-2',
#  'donut-bar-las-vegas',
#  'mto-café-las-vegas',
#  'joe-vicaris-andiamo-italian-steakhouse-las-vegas',
#  'therapy-las-vegas-5',
#  'triple-george-grill-las-vegas',
#  'the-laundry-room-las-vegas',
#  'nacho-daddy-downtown-las-vegas',
#  'publicus-las-vegas',
#  'park-on-fremont-las-vegas',
#  'fremont-street-experience-las-vegas',
#  'oak-and-ivy-las-vegas',
#  'the-goodwich-las-vegas',
#  'tacos-el-gordo-las-vegas',
#  'petronas-twin-towers-kuala-lumpur',
#  'marinis-on-57-kuala-lumpur',
#  'vcr-kuala-lumpur',
#  'din-tai-fung-kuala-lumpur-2',
#  'fuego-kuala-lumpur',
#  'klcc-park-kuala-lumpur-2',
#  'restoran-kin-kin-kuala-lumpur',
#  'madam-kwans-kuala-lumpur-5',
#  'feeka-coffee-roasters-kuala-lumpur-2',
#  'heli-lounge-bar-kuala-lumpur',
#  'taps-beer-bar-kuala-lumpur-2',
#  'opium-kuala-lumpur',
#  'skybar-kuala-lumpur-2',
#  'lot-10-hutong-kuala-lumpur-2',
#  'sushi-zanmai-kuala-lumpur',
#  'cantaloupe-kuala-lumpur',
#  'acme-bar-and-coffee-kuala-lumpur-2',
#  'bijan-kuala-lumpur',
#  'tgs-nasi-kandar-kuala-lumpur',
#  'food-republic-kuala-lumpur',
#  'two-brewers-windsor',
#  'bel-and-the-dragon-windsor',
#  'horse-and-groom-windsor',
#  'drury-house-restaurant-windsor',
#  'sebastians-italian-windsor',
#  'thai-square-windsor',
#  'wagamama-windsor',
#  'al-fassia-windsor',
#  'mango-lounge-windsor',
#  'bills-windsor',
#  'meimo-windsor',
#  'carpenters-arms-windsor',
#  'george-inn-windsor',
#  'gilbeys-windsor-2',
#  'the-duchess-of-cambridge-windsor',
#  'nandos-windsor',
#  'three-tuns-windsor',
#  'king-neptune-windsor',
#  'the-king-and-castle-windsor',
#  'viceroy-of-windsor-windsor-3',
#  'basilique-du-sacré-cœur-de-montmartre-paris-3',
#  'le-potager-du-père-thierry-paris-2',
#  'la-cave-gourmande-paris-2',
#  'pizzeria-babalou-paris',
#  'the-hardware-société-paris-2',
#  'soul-kitchen-paris',
#  'dirty-dick-paris',
#  'crêperie-brocéliande-paris-2',
#  'comptoir-de-la-gastronomie-paris-4',
#  'au-pied-du-sacré-coeur-paris-2',
#  'l-as-du-fallafel-paris',
#  'le-petit-canard-paris',
#  'cathédrale-notre-dame-de-paris-paris',
#  'al-caratello-paris-2',
#  'sacrée-fleur-paris-2',
#  'la-vache-et-le-cuisinier-paris',
#  'le-basilic-paris-3',
#  'guilo-guilo-paris',
#  'le-jardin-d-en-face-paris',
#  'opéra-national-de-paris-palais-garnier-paris',
#  'phipps-conservatory-and-botanical-gardens-pittsburgh',
#  'legume-pittsburgh',
#  'mount-everest-sushi-pittsburgh',
#  'las-palmas-pittsburgh',
#  'the-porch-at-schenley-pittsburgh',
#  'spice-island-tea-house-pittsburgh',
#  'noodlehead-pittsburgh',
#  'union-grill-pittsburgh',
#  'butterjoint-pittsburgh-3',
#  'redhawk-coffee-pittsburgh',
#  'church-brew-works-pittsburgh',
#  'mercurios-pittsburgh',
#  'oishii-bento-pittsburgh',
#  'crepes-parisiennes-pittsburgh-2',
#  'la-gourmandine-bakery-and-pastry-shop-pittsburgh',
#  'apteka-pittsburgh',
#  'p-and-gs-pamelas-diner-pittsburgh',
#  'tamarind-pittsburgh-2',
#  'espresso-a-mano-pittsburgh',
#  'yinzburgh-bbq-pittsburgh',
#  'central-park-new-york',
#  'two-little-red-hens-new-york-4',
#  'jacobs-pickles-new-york',
#  'the-halal-guys-new-york-2',
#  'calle-ocho-new-york',
#  'shake-shack-new-york-5',
#  'daniel-new-york-4',
#  'up-thai-new-york',
#  'candle-79-new-york',
#  'uva-new-york',
#  'sushi-yasaka-new-york',
#  'flex-mussels-new-york',
#  'lukes-lobster-upper-east-side-new-york',
#  'shake-shack-new-york-45',
#  'beard-papas-new-york',
#  'bibble-and-sip-new-york-2',
#  'kefi-new-york-2',
#  'the-mermaid-inn-new-york-2',
#  'flor-de-mayo-new-york-2',
#  'le-bernardin-new-york',
#  'mount-rushmore-national-memorial-keystone-2',
#  'powder-house-restaurant-keystone',
#  'carvers-cafe-keystone-3',
#  'the-cafe-keystone',
#  'black-hills-wilderness-edge-keystone',
#  'hoist-house-grill-keystone',
#  '富士山-富士宮市',
#  '吉田-須走口山頂-富士吉田市',
#  '富士山五合目富士急雲上閣-南都留郡',
#  '五合園レストハウス-南都留郡',
#  'dal-moros-venezia',
#  'rossopomodoro-venezia',
#  'la-zucca-venezia',
#  'osteria-alla-staffa-venezia',
#  'basilica-di-san-marco-venezia',
#  'canal-grande-venezia-2',
#  'antico-forno-venezia',
#  'a-le-tole-venezia',
#  'trattoria-al-gazzettino-venezia-4',
#  'palazzo-ducale-venezia',
#  'da-mamo-venezia-4',
#  'caffè-florian-venezia',
#  'ponte-di-rialto-venezia-2',
#  'cantina-do-mori-venezia',
#  'alla-rivetta-venezia',
#  'osteria-enoteca-san-marco-venezia',
#  'osteria-oliva-nera-venezia-2',
#  'trattoria-pontini-venezia-2',
#  'vineria-allamarone-venezia-3',
#  'la-rosa-rossa-venezia-2',
#  'osteria-del-bugiardo-verona',
#  'il-cenacolo-verona',
#  'antica-bottega-del-vino-verona-2',
#  'pizzeria-da-salvatore-verona',
#  'l-orologio-verona',
#  'al-pompiere-verona',
#  'casa-di-giulietta-verona',
#  'caffettiera-borsari-verona',
#  'greppia-verona',
#  'enoteca-cangrande-giotto-verona',
#  'du-de-cope-verona',
#  'locanda-4-cuochi-verona',
#  'le-cantine-de-l-arena-verona-3',
#  'osteria-casa-vino-verona',
#  'osteria-da-ugo-verona-2',
#  'la-griglia-verona',
#  'torcolo-verona',
#  'borsari-36-verona',
#  'antica-torreta-verona',
#  'alcova-del-frate-verona',
#  'pike-place-chowder-seattle',
#  'piroshky-piroshky-seattle',
#  'toulouse-petit-kitchen-and-lounge-seattle',
#  'the-pink-door-seattle-4',
#  'shiros-seattle',
#  'tilikum-place-cafe-seattle-3',
#  'lola-seattle',
#  'umi-sake-house-seattle',
#  'serious-pie-seattle',
#  'space-needle-seattle',
#  'the-crumpet-shop-seattle',
#  'le-panier-french-bakery-seattle',
#  'list-seattle',
#  'beechers-handmade-cheese-seattle',
#  'japonessa-seattle-4',
#  'biscuit-bitch-seattle',
#  'some-random-bar-seattle',
#  'kerry-park-seattle',
#  'skycity-at-the-needle-restaurant-seattle',
#  'storyville-coffee-company-seattle-9',
#  'big-ben-london',
#  'dishoom-london',
#  'westminster-abbey-london',
#  'coca-cola-london-eye-london',
#  'regency-café-london-2',
#  'gordons-wine-bar-london-4',
#  'houses-of-parliament-london-3',
#  'churchill-war-rooms-london-2',
#  'st-jamess-park-london-2',
#  'hawksmoor-seven-dials-london-4',
#  'the-wolseley-london',
#  'monmouth-coffee-london-3',
#  'hyde-park-london-2',
#  'yauatcha-london-7',
#  'flat-iron-london-2',
#  'dishoom-london-7',
#  'honest-burgers-london-2',
#  'nopi-london',
#  'shoryu-ramen-london',
#  ...]

# %%
e={'Distance':dist,'Price':price,'Country':country,'Rating':rating,'Review Count':reviewcount,'Monument':monument,'Food Type':types}
f=pd.DataFrame(e)
f
# Out:
#      Country     Distance                         Food Type  \
# 0         US    75.949926  Landmarks & Historical Buildings
# 1         US  1131.717451                           Museums
# 2         US  2377.859054  Landmarks & Historical Buildings
# 3         US  1798.598168                             Parks
# 4         US  2875.471385                          Barbeque
# 5         US  2997.020520                           Mexican
# 6         US  3169.119140                           Italian
# 7         US  3529.086258                             Cafes
# 8         US  2798.573094                             Cafes
# 9         US  3211.041203                            Korean
# 10        US  3481.055344                           Mexican
# 11        US  3072.465704                            Diners
# 12        US  3533.571550                    Latin American
# 13        US  2860.960719                         Wine Bars
# 14        US  3660.664814                           Seafood
# 15        US  3387.361990                              Thai
# 16        US  2251.398278                    American (New)
# 17        US  3478.706132                    American (New)
# 18        US  3409.467956                           Seafood
# 19        US  3002.990723                             Cafes
# 20        FR     0.245032  Landmarks & Historical Buildings
# 21        FR   539.225701                            French
# 22        FR    28.485776                            French
# 23        FR   968.852288                            Basque
# 24        FR  1719.026836  Landmarks & Historical Buildings
# 25        FR   510.634214                            French
# 26        FR  1308.196242                            French
# 27        FR   599.476459                            French
# 28        FR   872.740810                      Coffee & Tea
# 29        FR   852.051111                            French
# ...      ...          ...                               ...
# 1998      GB   402.476196                           Seafood
# 1999      GB   838.766301                             Parks
# 2000      GB   807.315996                            Indian
# 2001      GB   185.009563                          Japanese
# 2002      GB  1429.218319                             Parks
# 2003      GB   517.739153                      Coffee & Tea
# 2004      GB   496.144573                            Indian
# 2005      GB   842.060736  Landmarks & Historical Buildings
# 2006      GB   785.012293                      Local Flavor
# 2007      GB   324.588203                         Wine Bars
# 2008      GB   977.221358                            Indian
# 2009      GB   629.437268                           British
# 2010      GB   970.661308                          Churches
# 2011      GB  1073.089143                            French
# 2012      GB   709.530088                      Coffee & Tea
# 2013      GB   797.496882                           Dim Sum
# 2014      GB   774.335541                             Parks
# 2015      GB   896.993856                             Cafes
# 2016      GB   683.766278                           Burgers
# 2017      GB   648.707726  Landmarks & Historical Buildings
# 2018      GB   786.792622                            Indian
# 2019      GB   846.856197                       Steakhouses
# 2020      GB   666.256934                           Seafood
# 2021      GB     3.292181  Landmarks & Historical Buildings
# 2022      GB   825.628896                     Mediterranean
# 2023      GB   951.950317                           British
# 2024      FR  1159.465269  Landmarks & Historical Buildings
# 2025      FR   461.684361  Landmarks & Historical Buildings
# 2026      IE     7.113237  Landmarks & Historical Buildings
# 2027      IE   679.645933  Landmarks & Historical Buildings
#
#                    Monument Price  Rating  Review Count
# 0         Statue of Liberty   n/a     4.5           821
# 1         Statue of Liberty   n/a     4.5           291
# 2         Statue of Liberty   n/a     4.5           271
# 3         Statue of Liberty   n/a     4.5           178
# 4         Statue of Liberty     2     4.0           982
# 5         Statue of Liberty     1     4.0          1440
# 6         Statue of Liberty     2     4.0           595
# 7         Statue of Liberty     1     4.5           346
# 8         Statue of Liberty     2     4.0           522
# 9         Statue of Liberty     2     4.0           652
# 10        Statue of Liberty     2     4.0           793
# 11        Statue of Liberty     2     3.5          1149
# 12        Statue of Liberty     2     4.0           660
# 13        Statue of Liberty     3     4.0           546
# 14        Statue of Liberty     2     4.5           499
# 15        Statue of Liberty     2     4.5           252
# 16        Statue of Liberty     3     3.5           366
# 17        Statue of Liberty     2     4.0           837
# 18        Statue of Liberty     2     4.5           245
# 19        Statue of Liberty     1     4.5           159
# 20             Eiffel Tower   n/a     4.5          1641
# 21             Eiffel Tower     3     4.0           432
# 22             Eiffel Tower     4     4.0           353
# 23             Eiffel Tower     2     4.5           169
# 24             Eiffel Tower   n/a     4.5           568
# 25             Eiffel Tower     3     4.0           288
# 26             Eiffel Tower     2     4.5           304
# 27             Eiffel Tower     3     4.5           191
# 28             Eiffel Tower     1     4.5           206
# 29             Eiffel Tower     2     4.0           247
# ...                     ...   ...     ...           ...
# 1998      Piccadilly Circus     2     4.0           252
# 1999      Piccadilly Circus   n/a     4.5           166
# 2000      Piccadilly Circus     2     4.0           410
# 2001      Piccadilly Circus     2     4.0           297
# 2002      Piccadilly Circus   n/a     4.5           343
# 2003      Piccadilly Circus     2     4.0           420
# 2004       Trafalgar Square     2     4.5          1147
# 2005       Trafalgar Square   n/a     4.5           403
# 2006       Trafalgar Square   n/a     4.0           876
# 2007       Trafalgar Square     2     4.5           371
# 2008       Trafalgar Square     2     4.5           287
# 2009       Trafalgar Square     3     4.5           286
# 2010       Trafalgar Square   n/a     4.5           296
# 2011       Trafalgar Square     3     4.0           529
# 2012       Trafalgar Square     2     4.5           272
# 2013       Trafalgar Square     3     4.0           441
# 2014       Trafalgar Square   n/a     4.5           166
# 2015       Trafalgar Square     3     4.0           427
# 2016       Trafalgar Square     2     4.5           238
# 2017       Trafalgar Square   n/a     4.5           167
# 2018       Trafalgar Square     2     4.0           410
# 2019       Trafalgar Square     2     4.5           287
# 2020       Trafalgar Square     2     4.0           252
# 2021       Trafalgar Square   n/a     4.0           190
# 2022       Trafalgar Square     3     4.5           232
# 2023       Trafalgar Square     1     4.0           327
# 2024  Millau Bridge, France   n/a     4.0            31
# 2025  Millau Bridge, France   n/a     5.0             2
# 2026              Newgrange   n/a     5.0             2
# 2027              Newgrange   n/a     4.0             5
#
# [2028 rows x 7 columns]

# %%
f.to_csv('betterdata.csv')

# %%
#Averages grouped by price
f.groupby('Price').mean()
# Out:
#           Distance    Rating  Review Count
# Price
# 1      1306.166725  4.358333    543.750000
# 2      1116.034476  4.182857    659.915429
# 3      1018.255031  4.192661    514.519878
# 4       953.133474  4.351648    404.769231
# n/a    1095.372611  4.385057    236.825287

# %%
f.groupby('Country').mean().head()
# Out:
#             Distance    Rating  Review Count
# Country
# AR        522.647220  4.666667     17.666667
# AT        628.371613  4.300000     54.650000
# AU       1121.973694  4.166667    109.285714
# BE       2078.000116  4.125000    148.350000
# BR       2006.432972  4.428571     43.142857

# %%
g=f[f['Price']!='n/a']

# %%
g['Price']=g['Price'].astype(float)
# Out:
# C:\Users\J\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
xrange=[i for i in range(len(g['Price']))]

# %%
labels=["<500","500-1600","1600+"]
g['Distance']=pd.cut(g['Distance'],[0,500,1600,6000],labels=labels)
# Out:
# C:\Users\J\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
o=f.groupby('Rating')
for i in range(2,5):
    h=o.get_group(i)
    h.boxplot('Distance')
    plt.title(i)
    plt.show()

# %%
h=g.groupby('Distance')
for i in labels:
    j=h.get_group(i)
    j.boxplot('Rating')
    plt.title(i)
    plt.show()

# %%
h.get_group('1600+')
# Out:
#      Country Distance                  Food Type  \
# 4         US    1600+                   Barbeque
# 5         US    1600+                    Mexican
# 6         US    1600+                    Italian
# 7         US    1600+                      Cafes
# 8         US    1600+                      Cafes
# 9         US    1600+                     Korean
# 10        US    1600+                    Mexican
# 11        US    1600+                     Diners
# 12        US    1600+             Latin American
# 13        US    1600+                  Wine Bars
# 14        US    1600+                    Seafood
# 15        US    1600+                       Thai
# 16        US    1600+             American (New)
# 17        US    1600+             American (New)
# 18        US    1600+                    Seafood
# 19        US    1600+                      Cafes
# 52        GB    1600+                    Dim Sum
# 57        GB    1600+                     Indian
# 89        IT    1600+  Ice Cream & Frozen Yogurt
# 92        IT    1600+                Gluten-Free
# 94        IT    1600+                    Italian
# 99        IT    1600+                      Pizza
# 115       US    1600+                      Ramen
# 121       US    1600+                   Bakeries
# 122       US    1600+         Breakfast & Brunch
# 123       US    1600+              Mediterranean
# 125       US    1600+                   Hot Dogs
# 126       US    1600+                      Cafes
# 129       US    1600+            Performing Arts
# 130       US    1600+                 Sandwiches
# ...      ...      ...                        ...
# 1835      BE    1600+                      Cafes
# 1836      BE    1600+                   Japanese
# 1837      BE    1600+                    Seafood
# 1838      BE    1600+                    Burgers
# 1839      BE    1600+                      Greek
# 1840      BE    1600+                    Belgian
# 1841      BE    1600+                 Brasseries
# 1843      BE    1600+                    Belgian
# 1865      US    1600+                    Seafood
# 1868      US    1600+         Breakfast & Brunch
# 1870      US    1600+             American (New)
# 1873      US    1600+                      Pizza
# 1886      DK    1600+                      Cafes
# 1890      DK    1600+                     Danish
# 1906      US    1600+              Cocktail Bars
# 1907      US    1600+                    Mexican
# 1908      US    1600+                    Seafood
# 1910      US    1600+                      Cafes
# 1911      US    1600+                      Cafes
# 1912      US    1600+                    Italian
# 1913      US    1600+                     Korean
# 1914      US    1600+                  Wine Bars
# 1915      US    1600+                    Mexican
# 1917      US    1600+                   Barbeque
# 1918      US    1600+                     Diners
# 1920      US    1600+             Latin American
# 1922      US    1600+                    Seafood
# 1923      US    1600+                       Thai
# 1977      TR    1600+                    Turkish
# 1980      TR    1600+               Coffee & Tea
#
#                              Monument  Price  Rating  Review Count
# 4                   Statue of Liberty    2.0     4.0           982
# 5                   Statue of Liberty    1.0     4.0          1440
# 6                   Statue of Liberty    2.0     4.0           595
# 7                   Statue of Liberty    1.0     4.5           346
# 8                   Statue of Liberty    2.0     4.0           522
# 9                   Statue of Liberty    2.0     4.0           652
# 10                  Statue of Liberty    2.0     4.0           793
# 11                  Statue of Liberty    2.0     3.5          1149
# 12                  Statue of Liberty    2.0     4.0           660
# 13                  Statue of Liberty    3.0     4.0           546
# 14                  Statue of Liberty    2.0     4.5           499
# 15                  Statue of Liberty    2.0     4.5           252
# 16                  Statue of Liberty    3.0     3.5           366
# 17                  Statue of Liberty    2.0     4.0           837
# 18                  Statue of Liberty    2.0     4.5           245
# 19                  Statue of Liberty    1.0     4.5           159
# 52                            Big Ben    3.0     4.0           441
# 57                            Big Ben    2.0     4.5           287
# 89                          Colosseum    1.0     4.5           387
# 92                          Colosseum    3.0     4.5           178
# 94                          Colosseum    2.0     4.0           440
# 99                          Colosseum    1.0     4.5           160
# 115             Empire State Building    2.0     4.0          9234
# 121                    Hollywood Sign    1.0     4.5          7204
# 122                    Hollywood Sign    2.0     4.0          2815
# 123                    Hollywood Sign    3.0     4.0          1663
# 125                    Hollywood Sign    1.0     4.5           663
# 126                    Hollywood Sign    1.0     4.0           532
# 129                    Hollywood Sign    3.0     4.0          2065
# 130                    Hollywood Sign    2.0     4.0           496
# ...                               ...    ...     ...           ...
# 1835                Atomium, Brussels    1.0     4.5            65
# 1836                Atomium, Brussels    2.0     4.0            71
# 1837                Atomium, Brussels    3.0     4.5            32
# 1838                Atomium, Brussels    2.0     3.5           172
# 1839                Atomium, Brussels    3.0     4.0            59
# 1840                Atomium, Brussels    3.0     4.0            44
# 1841                Atomium, Brussels    3.0     4.0            24
# 1843                Atomium, Brussels    2.0     4.0            57
# 1865           Hollywood Walk of Fame    4.0     4.5          2341
# 1868           Hollywood Walk of Fame    2.0     4.0          5045
# 1870           Hollywood Walk of Fame    2.0     4.0          4169
# 1873           Hollywood Walk of Fame    2.0     4.0          3782
# 1886               Amalienborg Palace    1.0     4.5           165
# 1890               Amalienborg Palace    3.0     4.5           166
# 1906  Ellis Island Immigration Museum    2.0     4.0          1215
# 1907  Ellis Island Immigration Museum    1.0     4.0          1440
# 1908  Ellis Island Immigration Museum    2.0     4.5           915
# 1910  Ellis Island Immigration Museum    2.0     4.0           522
# 1911  Ellis Island Immigration Museum    1.0     4.5           346
# 1912  Ellis Island Immigration Museum    2.0     4.0           595
# 1913  Ellis Island Immigration Museum    2.0     4.0           652
# 1914  Ellis Island Immigration Museum    3.0     4.0           546
# 1915  Ellis Island Immigration Museum    2.0     4.0           793
# 1917  Ellis Island Immigration Museum    2.0     4.0           982
# 1918  Ellis Island Immigration Museum    2.0     3.5          1149
# 1920  Ellis Island Immigration Museum    2.0     4.0           660
# 1922  Ellis Island Immigration Museum    2.0     4.5           499
# 1923  Ellis Island Immigration Museum    2.0     4.5           252
# 1977            Blue Mosque, Istanbul    3.0     4.5            50
# 1980            Blue Mosque, Istanbul    1.0     4.5            40
#
# [337 rows x 7 columns]

# %%
f
# Out:
#      Country     Distance                         Food Type  \
# 0         US    75.949926  Landmarks & Historical Buildings
# 1         US  1131.717451                           Museums
# 2         US  2377.859054  Landmarks & Historical Buildings
# 3         US  1798.598168                             Parks
# 4         US  2875.471385                          Barbeque
# 5         US  2997.020520                           Mexican
# 6         US  3169.119140                           Italian
# 7         US  3529.086258                             Cafes
# 8         US  2798.573094                             Cafes
# 9         US  3211.041203                            Korean
# 10        US  3481.055344                           Mexican
# 11        US  3072.465704                            Diners
# 12        US  3533.571550                    Latin American
# 13        US  2860.960719                         Wine Bars
# 14        US  3660.664814                           Seafood
# 15        US  3387.361990                              Thai
# 16        US  2251.398278                    American (New)
# 17        US  3478.706132                    American (New)
# 18        US  3409.467956                           Seafood
# 19        US  3002.990723                             Cafes
# 20        FR     0.245032  Landmarks & Historical Buildings
# 21        FR   539.225701                            French
# 22        FR    28.485776                            French
# 23        FR   968.852288                            Basque
# 24        FR  1719.026836  Landmarks & Historical Buildings
# 25        FR   510.634214                            French
# 26        FR  1308.196242                            French
# 27        FR   599.476459                            French
# 28        FR   872.740810                      Coffee & Tea
# 29        FR   852.051111                            French
# ...      ...          ...                               ...
# 1998      GB   402.476196                           Seafood
# 1999      GB   838.766301                             Parks
# 2000      GB   807.315996                            Indian
# 2001      GB   185.009563                          Japanese
# 2002      GB  1429.218319                             Parks
# 2003      GB   517.739153                      Coffee & Tea
# 2004      GB   496.144573                            Indian
# 2005      GB   842.060736  Landmarks & Historical Buildings
# 2006      GB   785.012293                      Local Flavor
# 2007      GB   324.588203                         Wine Bars
# 2008      GB   977.221358                            Indian
# 2009      GB   629.437268                           British
# 2010      GB   970.661308                          Churches
# 2011      GB  1073.089143                            French
# 2012      GB   709.530088                      Coffee & Tea
# 2013      GB   797.496882                           Dim Sum
# 2014      GB   774.335541                             Parks
# 2015      GB   896.993856                             Cafes
# 2016      GB   683.766278                           Burgers
# 2017      GB   648.707726  Landmarks & Historical Buildings
# 2018      GB   786.792622                            Indian
# 2019      GB   846.856197                       Steakhouses
# 2020      GB   666.256934                           Seafood
# 2021      GB     3.292181  Landmarks & Historical Buildings
# 2022      GB   825.628896                     Mediterranean
# 2023      GB   951.950317                           British
# 2024      FR  1159.465269  Landmarks & Historical Buildings
# 2025      FR   461.684361  Landmarks & Historical Buildings
# 2026      IE     7.113237  Landmarks & Historical Buildings
# 2027      IE   679.645933  Landmarks & Historical Buildings
#
#                    Monument Price  Rating  Review Count
# 0         Statue of Liberty   n/a     4.5           821
# 1         Statue of Liberty   n/a     4.5           291
# 2         Statue of Liberty   n/a     4.5           271
# 3         Statue of Liberty   n/a     4.5           178
# 4         Statue of Liberty     2     4.0           982
# 5         Statue of Liberty     1     4.0          1440
# 6         Statue of Liberty     2     4.0           595
# 7         Statue of Liberty     1     4.5           346
# 8         Statue of Liberty     2     4.0           522
# 9         Statue of Liberty     2     4.0           652
# 10        Statue of Liberty     2     4.0           793
# 11        Statue of Liberty     2     3.5          1149
# 12        Statue of Liberty     2     4.0           660
# 13        Statue of Liberty     3     4.0           546
# 14        Statue of Liberty     2     4.5           499
# 15        Statue of Liberty     2     4.5           252
# 16        Statue of Liberty     3     3.5           366
# 17        Statue of Liberty     2     4.0           837
# 18        Statue of Liberty     2     4.5           245
# 19        Statue of Liberty     1     4.5           159
# 20             Eiffel Tower   n/a     4.5          1641
# 21             Eiffel Tower     3     4.0           432
# 22             Eiffel Tower     4     4.0           353
# 23             Eiffel Tower     2     4.5           169
# 24             Eiffel Tower   n/a     4.5           568
# 25             Eiffel Tower     3     4.0           288
# 26             Eiffel Tower     2     4.5           304
# 27             Eiffel Tower     3     4.5           191
# 28             Eiffel Tower     1     4.5           206
# 29             Eiffel Tower     2     4.0           247
# ...                     ...   ...     ...           ...
# 1998      Piccadilly Circus     2     4.0           252
# 1999      Piccadilly Circus   n/a     4.5           166
# 2000      Piccadilly Circus     2     4.0           410
# 2001      Piccadilly Circus     2     4.0           297
# 2002      Piccadilly Circus   n/a     4.5           343
# 2003      Piccadilly Circus     2     4.0           420
# 2004       Trafalgar Square     2     4.5          1147
# 2005       Trafalgar Square   n/a     4.5           403
# 2006       Trafalgar Square   n/a     4.0           876
# 2007       Trafalgar Square     2     4.5           371
# 2008       Trafalgar Square     2     4.5           287
# 2009       Trafalgar Square     3     4.5           286
# 2010       Trafalgar Square   n/a     4.5           296
# 2011       Trafalgar Square     3     4.0           529
# 2012       Trafalgar Square     2     4.5           272
# 2013       Trafalgar Square     3     4.0           441
# 2014       Trafalgar Square   n/a     4.5           166
# 2015       Trafalgar Square     3     4.0           427
# 2016       Trafalgar Square     2     4.5           238
# 2017       Trafalgar Square   n/a     4.5           167
# 2018       Trafalgar Square     2     4.0           410
# 2019       Trafalgar Square     2     4.5           287
# 2020       Trafalgar Square     2     4.0           252
# 2021       Trafalgar Square   n/a     4.0           190
# 2022       Trafalgar Square     3     4.5           232
# 2023       Trafalgar Square     1     4.0           327
# 2024  Millau Bridge, France   n/a     4.0            31
# 2025  Millau Bridge, France   n/a     5.0             2
# 2026              Newgrange   n/a     5.0             2
# 2027              Newgrange   n/a     4.0             5
#
# [2028 rows x 7 columns]

# %%
review=[]
tweets=[]
vader=[]
for i in jds:
    url=f'https://api.yelp.com/v3/businesses/{i}/reviews'
    c=requests.get(url,headers=headers).json()
    try:
        for j in c['reviews']:
            review.append(j['rating'])
            tweets.append(j['text'])
            vader.append(analyzer.polarity_scores(j["text"])["compound"])
    except:
        break
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-189-775b2e048fae> in <module>()
#       5     url=f'https://api.yelp.com/v3/businesses/{i}/reviews'
#       6     c=requests.get(url,headers=headers).json()
# ----> 7     for j in c['reviews']:
#       8         review.append(j['rating'])
#       9         tweets.append(j['text'])
#
# KeyError: 'reviews'

# %%
plt.scatter(vader,review)
plt.show()

# %%
c['reviews'][0]
# Out:
# {'id': 'HyuACkSh6EhMW1pi3NVGFw',
#  'rating': 5,
#  'text': 'I have had the privilege of seeing the Statue of Liberty twice in my lifetime and it is absolutely breathtaking. To me, it symbolizes America and everything...',
#  'time_created': '2018-02-19 23:08:48',
#  'url': 'https://www.yelp.com/biz/statue-of-liberty-new-york-3?hrid=HyuACkSh6EhMW1pi3NVGFw&adjust_creative=M7mV67MJ1KtmqjorxVLbyA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=M7mV67MJ1KtmqjorxVLbyA',
#  'user': {'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/c6KFcSP8zXpybm21TjzUgQ/o.jpg',
#   'name': 'Lance L.'}}

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
